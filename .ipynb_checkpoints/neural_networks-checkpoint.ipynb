# %% [markdown]
# # Image Classification With Neural Networks

# %% [markdown]
# ## Chest X-ray Images (Pneumonia)

# %%
#importing relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential
from keras import layers, models, regularizers, optimizers
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %% [markdown]
# ![xray.jpg](attachment:xray.jpg)

# %%
# Set the paths to train, test, and validation folders
train_folder = 'Data/train'
test_folder = 'Data/test'
val_folder = 'Data/val'

# %%
# Downsampling the images to 128X128 pixels
downsampled_size = (128, 128)

# Rescale pixel values between 0 and 1
datagen = ImageDataGenerator(rescale=1./255)  

# Load the train data
train_generator = datagen.flow_from_directory(
    train_folder,
    target_size=downsampled_size,
    batch_size=5216,
    class_mode='binary',
    shuffle=True
)

# Load the test data
test_generator = datagen.flow_from_directory(
    test_folder,
    target_size=downsampled_size,
    batch_size=624,
    class_mode='binary',
    shuffle=False
)

# Load the validation data
val_generator = datagen.flow_from_directory(
    val_folder,
    target_size=downsampled_size,
    batch_size=16,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.

# %% [markdown]
# *  This dataset is separated into three folders. The "train" folder contains 5,216 images, the "validation" folder has 624 images, and the "test" folder contains 16 images.
# * Each folder consists of two classes. One class represents normal chest X-rays, and the other class represents chest X-rays with pneumonia.
#
# In the next step, we will perform exploratory data analysis (EDA) to examine the class distribution.

# %% [markdown]
# ## Explanatory Data Analysis

# %%
## Retrieve the dictionary of class indices from the train_generator
dict_class = train_generator.class_indices
print('Dictionary: {}'.format(dict_class))
class_names = list(dict_class.keys())
# Print the list of class labels
print('Class labels: {}'.format(class_names))
# Out:
# Dictionary: {'NORMAL': 0, 'PNEUMONIA': 1}
# Class labels: ['NORMAL', 'PNEUMONIA']

# %%
# Get a batch of images from the train generator
batch = next(train_generator)

# Extract the images and labels from the batch
images, labels = batch

# Display the first few images with their corresponding labels
num_images = 6

fig, axes = plt.subplots(2, 3, figsize=(10, 10))
for i in range(num_images):
    axes[i//3, i%3].imshow(images[i], cmap='RdBu')
    axes[i//3, i%3].set_title('Label: {}'.format(labels[i]))
    axes[i//3, i%3].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Class 0 represents chest X-ray images without pneumonia, while class 1 contains images with pneumonia. Differentiating between these two classes is challenging due to their visual similarity. Therefore, there is a need for a more accurate and effective model that can easily distinguish between them and improve pneumonia detection.

# %%
"""Function to visualization class distributions"""
def plot_class_counts(labels, title):
    # Get the counts for each class
    class_labels, counts = np.unique(labels, return_counts=True)
    # Calculate the percentage of value counts
    total_count = np.sum(counts)
    percentages = counts / total_count * 100
    # Plot the results
    plt.figure(figsize=(12,10))
    plt.title(f'{title}', fontsize='20')
    plt.xlabel("Classes")
    plt.ylabel("Count")
    # Replace "1" with "Normal" in class_labels list
    class_labels = ['Pneumonia', 'Normal']
    # Add value counts as text on top of each bar
    for i in range(len(class_labels)):
        plt.text(i, counts[i], f"{counts[i]}\n{percentages[i]:.2f}%", ha='left', va='top')
    sns.barplot(x=class_labels, y=counts)
    plt.show()

# %%
#training data distribution
labels = train_generator.classes
plot_class_counts(labels, 'Training Data Distribution')

# %%
#test data distribution
test_labels = test_generator.classes
plot_class_counts(test_labels, 'Test Data Distribution')

# %%
#validation data distribution
vals_labels = val_generator.classes
plot_class_counts(vals_labels, 'Validation Data Distribution')

# %%
from PIL import Image
normal_image_sizes = []
pneumonia_image_sizes = []
for image_path in train_generator.filepaths:
    img = Image.open(image_path)
    width, height = img.size
    if "NORMAL" in image_path:
        normal_image_sizes.append((width, height))
    else:
        pneumonia_image_sizes.append((width, height))
normal_image_sizes = np.array(normal_image_sizes)
pneumonia_image_sizes = np.array(pneumonia_image_sizes)
plt.scatter(normal_image_sizes[:, 0], normal_image_sizes[:, 1], label='Normal')
plt.scatter(pneumonia_image_sizes[:, 0], pneumonia_image_sizes[:, 1], label='Pneumonia')
plt.xlabel('Width')
plt.ylabel('Height')
plt.title('Image Size Distribution')
plt.legend()
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Steps involved here are
# * Obtaining images and labels from the train generator:The images and labels are returned as arrays. The train_images array contains the image data, and the train_labels array contains the corresponding labels.
# * reshaping the image array.

# %%
# obtain images and labels from the test generator
train_images, train_labels = next(train_generator)
test_images, test_labels = next(test_generator)
val_images, val_labels = next(val_generator)

# %%
# Explore the shape of the images and labels
m_train = train_images.shape[0]
num_px = train_images.shape[1]
m_test = test_images.shape[0]
m_val = val_images.shape[0]

print ("Number of training samples: " + str(m_train))
print ("Number of testing samples: " + str(m_test))
print ("Number of validation samples: " + str(m_val))
print ("train_images shape: " + str(train_images.shape))
print ("train_labels shape: " + str(train_labels.shape))
print ("test_images shape: " + str(test_images.shape))
print ("test_labels shape: " + str(test_labels.shape))
print ("val_images shape: " + str(val_images.shape))
print ("val_labels shape: " + str(val_labels.shape))
# Out:
# Number of training samples: 5216
# Number of testing samples: 624
# Number of validation samples: 16
# train_images shape: (5216, 128, 128, 3)
# train_labels shape: (5216,)
# test_images shape: (624, 128, 128, 3)
# test_labels shape: (624,)
# val_images shape: (16, 128, 128, 3)
# val_labels shape: (16,)

# %%
# Reshaping the images
train_img = train_images.reshape(train_images.shape[0], -1)
test_img = test_images.reshape(test_images.shape[0], -1)
val_img = val_images.reshape(val_images.shape[0], -1)

print(train_img.shape)
print(test_img.shape)
print(val_img.shape)
# Out:
# (5216, 49152)
# (624, 49152)
# (16, 49152)

# %% [markdown]
# ## Modelling

# %% [markdown]
# # Baseline model : A Densely Connected Neural Network

# %%
# Build a baseline fully connected network

#intialize a sequential model
model_1 = models.Sequential()

#2 layers with relu activation
model_1.add(layers.Dense(64, activation='relu', input_shape=(49152,))) 
model_1.add(layers.Dense(32, activation='relu'))

#one layer with sigmoid activation
model_1.add(layers.Dense(1, activation='sigmoid'))

# %%
#compile the model
model_1.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Let's inspect the shape of our model before training it and see how many training parameters we have.

# %%
model_1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 64)                3145792
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 3,147,905
# Trainable params: 3,147,905
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * 3,145,792 trainable parameters!

# %%
#train the model
results_1 = model_1.fit(train_img,
                    train_labels,
                    epochs=10,
                    batch_size=100,

                    validation_data=(val_img, val_labels))
# Out:
# Epoch 1/10
# 53/53 [==============================] - 3s 56ms/step - loss: 0.5604 - accuracy: 0.7544 - val_loss: 1.4482 - val_accuracy: 0.5000
# Epoch 2/10
# 53/53 [==============================] - 3s 48ms/step - loss: 0.4467 - accuracy: 0.8089 - val_loss: 0.5580 - val_accuracy: 0.6875
# Epoch 3/10
# 53/53 [==============================] - 2s 46ms/step - loss: 0.3647 - accuracy: 0.8443 - val_loss: 0.8149 - val_accuracy: 0.6250
# Epoch 4/10
# 53/53 [==============================] - 3s 49ms/step - loss: 0.3377 - accuracy: 0.8606 - val_loss: 0.6431 - val_accuracy: 0.6875
# Epoch 5/10
# 53/53 [==============================] - 2s 47ms/step - loss: 0.2969 - accuracy: 0.8815 - val_loss: 0.4002 - val_accuracy: 0.8125
# Epoch 6/10
# 53/53 [==============================] - 3s 50ms/step - loss: 0.2736 - accuracy: 0.8903 - val_loss: 1.7509 - val_accuracy: 0.5000
# Epoch 7/10
# 53/53 [==============================] - 3s 48ms/step - loss: 0.2312 - accuracy: 0.9082 - val_loss: 0.8766 - val_accuracy: 0.6250
# Epoch 8/10
# 53/53 [==============================] - 3s 52ms/step - loss: 0.1974 - accuracy: 0.9239 - val_loss: 0.6535 - val_accuracy: 0.7500
# Epoch 9/10
# 53/53 [==============================] - 3s 49ms/step - loss: 0.2233 - accuracy: 0.9183 - val_loss: 0.4804 - val_accuracy: 0.8125
# Epoch 10/10
# 53/53 [==============================] - 2s 47ms/step - loss: 0.1907 - accuracy: 0.9243 - val_loss: 0.6190 - val_accuracy: 0.7500

# %% [markdown]
# Now, let's inspect the model's performance and see if we detect any overfitting or other issues by plotting:
#
# * The loss and val_loss over the training epochs
# * The acc and val_acc over the training epochs

# %%
"""Function to plot the loss function"""
def visualize_training_results_dense(results):
    history = results.history
    plt.figure()
    plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss', 'loss'])
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()
    
    plt.figure()
    plt.plot(history['val_accuracy'])
    plt.plot(history['accuracy'])
    plt.legend(['val_acc', 'acc'])
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
visualize_training_results_dense(results_1)

# %%
results_train = model_1.evaluate(train_img, train_labels)
results_train
# Out:
# 163/163 [==============================] - 2s 11ms/step - loss: 0.1691 - accuracy: 0.9302
# [0.16913944482803345, 0.9302147030830383]

# %%
results_test = model_1.evaluate(val_img, val_labels)
results_test
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 0.6190 - accuracy: 0.7500
# [0.6189963817596436, 0.75]

# %% [markdown]
# # model 2: CNN

# %%
#initialize a sequential model 
model_2 = models.Sequential()

#add 2 convolutional layers with pooling
model_2.add(layers.Conv2D(64, (3, 3), activation='relu',
                        input_shape=(128 , 128,  3)))
model_2.add(layers.MaxPooling2D((2, 2)))

model_2.add(layers.Conv2D(32, (3,3), activation='relu'))
model_2.add(layers.MaxPooling2D((2, 2)))


model_2.add(layers.Flatten())
model_2.add(layers.Dense(1, activation='sigmoid'))

# %%
model_2.compile(loss='binary_crossentropy',
              optimizer="sgd",
              metrics=['acc'])

model_2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 126, 126, 64)      1792
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 61, 61, 32)        18464
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 28800)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 28801
# =================================================================
# Total params: 49,057
# Trainable params: 49,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
"""Function to plot the loss function"""
def visualize_training_results(results):
    history = results.history
    plt.figure()
    plt.plot(history['val_loss'])
    plt.plot(history['loss'])
    plt.legend(['val_loss', 'loss'])
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.show()
    
    plt.figure()
    plt.plot(history['val_acc'])
    plt.plot(history['accu'])
    plt.legend(['val_acc', 'acc'])
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.show()

# %%
results_2 = model_2.fit(train_images,
                    train_labels,
                    epochs=10,
                    batch_size=100,
                    validation_data=(val_images, val_labels))
# Out:
# Epoch 1/10
# 53/53 [==============================] - 140s 3s/step - loss: 0.5452 - acc: 0.7488 - val_loss: 0.6907 - val_acc: 0.5625
# Epoch 2/10
# 53/53 [==============================] - 140s 3s/step - loss: 0.4655 - acc: 0.7943 - val_loss: 0.6634 - val_acc: 0.6250
# Epoch 3/10
# 53/53 [==============================] - 143s 3s/step - loss: 0.3947 - acc: 0.8386 - val_loss: 0.9530 - val_acc: 0.6250
# Epoch 4/10
# 53/53 [==============================] - 144s 3s/step - loss: 0.3254 - acc: 0.8622 - val_loss: 1.1080 - val_acc: 0.6250
# Epoch 5/10
# 53/53 [==============================] - 145s 3s/step - loss: 0.2892 - acc: 0.8917 - val_loss: 0.6368 - val_acc: 0.6250
# Epoch 6/10
# 53/53 [==============================] - 135s 3s/step - loss: 0.2244 - acc: 0.9114 - val_loss: 0.3874 - val_acc: 0.8125
# Epoch 7/10
# 53/53 [==============================] - 135s 3s/step - loss: 0.2224 - acc: 0.9032 - val_loss: 0.8089 - val_acc: 0.6250
# Epoch 8/10
# 53/53 [==============================] - 134s 3s/step - loss: 0.1914 - acc: 0.9222 - val_loss: 0.4779 - val_acc: 0.8125
# Epoch 9/10
# 53/53 [==============================] - 136s 3s/step - loss: 0.1942 - acc: 0.9270 - val_loss: 0.3026 - val_acc: 0.8750
# Epoch 10/10
# 53/53 [==============================] - 139s 3s/step - loss: 0.1664 - acc: 0.9314 - val_loss: 0.4983 - val_acc: 0.7500

# %%
#visualizing loss and accuracy for the cnn model
visualize_training_results(results_2)

# %%
#evaluating cnn
results_train = model_2.evaluate(train_images, train_labels)
results_train
# Out:
# 163/163 [==============================] - 41s 250ms/step - loss: 0.1420 - acc: 0.9457
# [0.14196790754795074, 0.9457438588142395]

# %%
results_test = model_2.evaluate(val_images, val_labels)
results_test
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 0.4983 - acc: 0.7500
# [0.49831950664520264, 0.75]

# %% [markdown]
# # Tuning CNN

# %% [markdown]
# ##  Model 3 - CNN with Regularization and Dropout

# %%
model_3 = models.Sequential()
model_3.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
model_3.add(layers.MaxPooling2D((2, 2)))
model_3.add(layers.Dropout(0.25))  # Dropout layer with a rate of 0.25

# L1 and L2 regularization with a factor of 0.01
model_3.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01))) 
model_3.add(layers.MaxPooling2D((2, 2)))
model_3.add(layers.Dropout(0.25))

# L1 and L2 regularization with a factor of 0.01
model_3.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01)))
model_3.add(layers.MaxPooling2D((2, 2)))
model_3.add(layers.Dropout(0.25))

model_3.add(layers.Flatten())
model_3.add(layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01)))
model_3.add(layers.Dense(1, activation='sigmoid'))

# %%
model_3.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
results_3 = model_3.fit(train_images,
                    train_labels,
                    epochs=20,
                    batch_size=32,
                    validation_data=(val_images, val_labels))
# Out:
# Epoch 1/20
# 163/163 [==============================] - 144s 882ms/step - loss: 10.8053 - accuracy: 0.7410 - val_loss: 1.8381 - val_accuracy: 0.5000
# Epoch 2/20
# 163/163 [==============================] - 101s 618ms/step - loss: 1.6389 - accuracy: 0.7429 - val_loss: 1.8178 - val_accuracy: 0.5000
# Epoch 3/20
# 163/163 [==============================] - 82s 502ms/step - loss: 1.6236 - accuracy: 0.7429 - val_loss: 1.8298 - val_accuracy: 0.5000
# Epoch 4/20
# 163/163 [==============================] - 82s 500ms/step - loss: 1.6071 - accuracy: 0.7429 - val_loss: 1.8390 - val_accuracy: 0.5000
# Epoch 5/20
# 163/163 [==============================] - 82s 502ms/step - loss: 1.5970 - accuracy: 0.7429 - val_loss: 1.8559 - val_accuracy: 0.5000
# Epoch 6/20
# 163/163 [==============================] - 82s 501ms/step - loss: 1.5824 - accuracy: 0.7429 - val_loss: 1.8349 - val_accuracy: 0.5000
# Epoch 7/20
# 163/163 [==============================] - 82s 503ms/step - loss: 1.5788 - accuracy: 0.7429 - val_loss: 1.8349 - val_accuracy: 0.5000
# Epoch 8/20
# 163/163 [==============================] - 83s 510ms/step - loss: 1.5719 - accuracy: 0.7429 - val_loss: 1.8303 - val_accuracy: 0.5000
# Epoch 9/20
# 163/163 [==============================] - 82s 504ms/step - loss: 1.5734 - accuracy: 0.7429 - val_loss: 1.8413 - val_accuracy: 0.5000
# Epoch 10/20
# 163/163 [==============================] - 82s 502ms/step - loss: 1.5857 - accuracy: 0.7429 - val_loss: 1.8545 - val_accuracy: 0.5000
# Epoch 11/20
# 163/163 [==============================] - 84s 514ms/step - loss: 1.5791 - accuracy: 0.7429 - val_loss: 1.8305 - val_accuracy: 0.5000
# Epoch 12/20
# 163/163 [==============================] - 83s 508ms/step - loss: 1.5689 - accuracy: 0.7429 - val_loss: 1.8280 - val_accuracy: 0.5000
# Epoch 13/20
# 163/163 [==============================] - 82s 502ms/step - loss: 1.5719 - accuracy: 0.7429 - val_loss: 1.8261 - val_accuracy: 0.5000
# Epoch 14/20
# 163/163 [==============================] - 82s 506ms/step - loss: 1.5755 - accuracy: 0.7429 - val_loss: 1.8477 - val_accuracy: 0.5000
# Epoch 15/20
# 163/163 [==============================] - 81s 500ms/step - loss: 1.5828 - accuracy: 0.7429 - val_loss: 1.8306 - val_accuracy: 0.5000
# Epoch 16/20
# 163/163 [==============================] - 82s 502ms/step - loss: 1.5768 - accuracy: 0.7429 - val_loss: 1.8284 - val_accuracy: 0.5000
# Epoch 17/20
# 163/163 [==============================] - 81s 495ms/step - loss: 1.5700 - accuracy: 0.7429 - val_loss: 1.8433 - val_accuracy: 0.5000
# Epoch 18/20
# 163/163 [==============================] - 80s 494ms/step - loss: 1.5702 - accuracy: 0.7429 - val_loss: 1.8170 - val_accuracy: 0.5000
# Epoch 19/20
# 163/163 [==============================] - 81s 495ms/step - loss: 1.5659 - accuracy: 0.7429 - val_loss: 1.8225 - val_accuracy: 0.5000
# Epoch 20/20
# 163/163 [==============================] - 80s 493ms/step - loss: 1.5688 - accuracy: 0.7429 - val_loss: 1.8337 - val_accuracy: 0.5000

# %%
visualize_training_results(results_3)

# %%
#evaluating 
results_train = model_3.evaluate(train_images, train_labels)
results_train
# Out:
# 163/163 [==============================] - 21s 126ms/step - loss: 1.5645 - accuracy: 0.7429
# [1.5644797086715698, 0.7429064512252808]

# %%
results_test = model_3.evaluate(val_images, val_labels)
results_test
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 1.8337 - accuracy: 0.5000
# [1.833672285079956, 0.5]

# %% [markdown]
# ## Model 4 - CNN with Architecture modifications

# %% [markdown]
# we've modified the architecture of the model by adding more convolutional layers and increasing the number of filters in each layer. Additionally, we've introduced two additional dense layers after the flattening layer.

# %%
model_4 = models.Sequential()
model_4.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
model_4.add(layers.MaxPooling2D((2, 2)))

model_4.add(layers.Conv2D(64, (3, 3), activation='relu'))
model_4.add(layers.MaxPooling2D((2, 2)))

model_4.add(layers.Conv2D(128, (3, 3), activation='relu'))
model_4.add(layers.MaxPooling2D((2, 2)))

model_4.add(layers.Conv2D(128, (3, 3), activation='relu'))
model_4.add(layers.MaxPooling2D((2, 2)))


model_4.add(layers.Conv2D(256, (3, 3), activation='relu'))
model_4.add(layers.MaxPooling2D((2, 2)))

model_4.add(layers.Flatten())
model_4.add(layers.Dense(512, activation='relu'))
model_4.add(layers.Dense(256, activation='relu'))
model_4.add(layers.Dense(1, activation='sigmoid'))

# %%
model_4.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
results_4 = model_4.fit(train_images,
                    train_labels,
                    epochs=10,
                    batch_size=100,
                    validation_data=(val_images, val_labels))
# Out:
# Epoch 1/10
# 53/53 [==============================] - 90s 2s/step - loss: 0.5676 - accuracy: 0.7326 - val_loss: 0.6827 - val_accuracy: 0.5625
# Epoch 2/10
# 53/53 [==============================] - 93s 2s/step - loss: 0.6036 - accuracy: 0.7222 - val_loss: 0.8142 - val_accuracy: 0.5000
# Epoch 3/10
# 53/53 [==============================] - 87s 2s/step - loss: 0.5667 - accuracy: 0.7441 - val_loss: 1.0107 - val_accuracy: 0.5000
# Epoch 4/10
# 53/53 [==============================] - 90s 2s/step - loss: 0.3470 - accuracy: 0.8639 - val_loss: 0.5557 - val_accuracy: 0.6875
# Epoch 5/10
# 53/53 [==============================] - 86s 2s/step - loss: 0.1880 - accuracy: 0.9233 - val_loss: 0.9616 - val_accuracy: 0.5625
# Epoch 6/10
# 53/53 [==============================] - 88s 2s/step - loss: 0.1237 - accuracy: 0.9502 - val_loss: 0.8764 - val_accuracy: 0.6875
# Epoch 7/10
# 53/53 [==============================] - 86s 2s/step - loss: 0.0854 - accuracy: 0.9682 - val_loss: 0.1060 - val_accuracy: 1.0000
# Epoch 8/10
# 53/53 [==============================] - 88s 2s/step - loss: 0.0679 - accuracy: 0.9743 - val_loss: 0.0438 - val_accuracy: 1.0000
# Epoch 9/10
# 53/53 [==============================] - 89s 2s/step - loss: 0.0658 - accuracy: 0.9751 - val_loss: 0.0597 - val_accuracy: 1.0000
# Epoch 10/10
# 53/53 [==============================] - 86s 2s/step - loss: 0.0562 - accuracy: 0.9795 - val_loss: 0.0948 - val_accuracy: 1.0000

# %%
visualize_training_results(results_4)

# %%
#evaluating 
results_train = model_4.evaluate(train_images, train_labels)
results_train
# Out:
# 163/163 [==============================] - 24s 149ms/step - loss: 0.0448 - accuracy: 0.9827
# [0.04482447728514671, 0.9827454090118408]

# %%
results_test = model_4.evaluate(val_images, val_labels)
results_test
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 0.0948 - accuracy: 1.0000
# [0.09484552592039108, 1.0]

# %%
model_5 = models.Sequential()
model_5.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
model_5.add(layers.MaxPooling2D((2, 2)))
model_5.add(layers.Dropout(0.25))  # Dropout layer with a rate of 0.25

# L1 and L2 regularization with a factor of 0.01
model_5.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01))) 
model_5.add(layers.MaxPooling2D((2, 2)))
model_5.add(layers.Dropout(0.25))

# L1 and L2 regularization with a factor of 0.01
model_5.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01)))
model_5.add(layers.MaxPooling2D((2, 2)))
model_5.add(layers.Dropout(0.25))

# L1 and L2 regularization with a factor of 0.01
model_5.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01)))
model_5.add(layers.MaxPooling2D((2, 2)))
model_5.add(layers.Dropout(0.25))

model_5.add(layers.Flatten())
model_5.add(layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.01, l2=0.01)))
model_5.add(layers.Dense(1, activation='sigmoid'))

model_5.add(layers.Flatten())
model_5.add(layers.Dense(512, activation='relu'))
model_5.add(layers.Dense(256, activation='relu'))
model_5.add(layers.Dense(1, activation='sigmoid'))

# %%
model_5.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
results_5 = model_5.fit(train_images,
                    train_labels,
                    epochs=10,
                    batch_size=100,
                    validation_data=(val_images, val_labels))
# Out:
# Epoch 1/10
# 53/53 [==============================] - 93s 2s/step - loss: 48.8665 - accuracy: 0.7318 - val_loss: 6.3609 - val_accuracy: 0.5000
# Epoch 2/10
# 53/53 [==============================] - 84s 2s/step - loss: 2.5425 - accuracy: 0.7429 - val_loss: 1.7725 - val_accuracy: 0.5000
# Epoch 3/10
# 53/53 [==============================] - 84s 2s/step - loss: 1.4794 - accuracy: 0.7429 - val_loss: 1.6891 - val_accuracy: 0.5000
# Epoch 4/10
# 53/53 [==============================] - 84s 2s/step - loss: 1.4636 - accuracy: 0.7429 - val_loss: 1.6961 - val_accuracy: 0.5000
# Epoch 5/10
# 53/53 [==============================] - 84s 2s/step - loss: 1.4608 - accuracy: 0.7429 - val_loss: 1.6758 - val_accuracy: 0.5000
# Epoch 6/10
# 53/53 [==============================] - 85s 2s/step - loss: 1.4570 - accuracy: 0.7429 - val_loss: 1.7462 - val_accuracy: 0.5000
# Epoch 7/10
# 53/53 [==============================] - 100s 2s/step - loss: 1.4510 - accuracy: 0.7429 - val_loss: 1.7284 - val_accuracy: 0.5000
# Epoch 8/10
# 53/53 [==============================] - 84s 2s/step - loss: 1.4483 - accuracy: 0.7429 - val_loss: 1.7244 - val_accuracy: 0.5000
# Epoch 9/10
# 53/53 [==============================] - 85s 2s/step - loss: 1.4468 - accuracy: 0.7429 - val_loss: 1.6900 - val_accuracy: 0.5000
# Epoch 10/10
# 53/53 [==============================] - 85s 2s/step - loss: 1.4416 - accuracy: 0.7429 - val_loss: 1.7052 - val_accuracy: 0.5000

# %%
visualize_training_results(results_5)

# %%
#evaluating 
results_train = model_5.evaluate(train_images, train_labels)
results_train
# Out:
# 163/163 [==============================] - 24s 146ms/step - loss: 1.4357 - accuracy: 0.7429
# [1.43569815158844, 0.7429064512252808]

# %%
results_test = model_5.evaluate(val_images, val_labels)
results_test
# Out:
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7052 - accuracy: 0.5000
# [1.7051810026168823, 0.5]

# %% [markdown]
# ## Model 6 - CNN with Transfer Learning

# %%
from keras.applications import VGG19
cnn_base = VGG19(weights='imagenet', 
                 include_top=False, 
                 input_shape=(64, 64, 3))

# %%
cnn_base.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_6 = models.Sequential()
model_6.add(cnn_base)
model_6.add(layers.Flatten())
model_6.add(layers.Dense(132, activation='relu'))
model_6.add(layers.Dense(1, activation='sigmoid'))

# %%
# You can check whether a layer is trainable (or alter its setting) through the layer.trainable attribute
for layer in model_6.layers:
    print(layer.name, layer.trainable)
    
# Similarly, you can check how many trainable weights are in the model
print(len(model_6.trainable_weights))
# Out:
# vgg19 True
# flatten_21 True
# dense_53 True
# dense_54 True
# 36

# %%
cnn_base.trainable = False

# %%
# You can check whether a layer is trainable (or alter its setting) through the layer.trainable attribute
for layer in model_6.layers:
    print(layer.name, layer.trainable)
    
# Similarly, we can check how many trainable weights are in the model
print(len(model_6.trainable_weights))
# Out:
# vgg19 False
# flatten_21 True
# dense_53 True
# dense_54 True
# 4

# %%
model_6.compile(loss='binary_crossentropy',
              optimizer=optimizers.RMSprop(learning_rate=2e-5),
              metrics=['acc'])

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# Resize the train_images and val_images to (64, 64)
train_images_resized = np.array([image.smart_resize(img, (64, 64)) for img in train_images])
val_images_resized = np.array([image.smart_resize(img, (64, 64)) for img in val_images])

# Train the model with the resized images
results_6 = model_6.fit(train_images_resized,
                        train_labels,
                        epochs=10,
                        batch_size=100,
                        validation_data=(val_images_resized, val_labels))
# Out:
# Epoch 1/10
# 53/53 [==============================] - 137s 3s/step - loss: 0.5555 - acc: 0.7429 - val_loss: 0.7677 - val_acc: 0.5000
# Epoch 2/10
# 53/53 [==============================] - 133s 3s/step - loss: 0.4477 - acc: 0.7490 - val_loss: 0.6851 - val_acc: 0.5000
# Epoch 3/10
# 53/53 [==============================] - 135s 3s/step - loss: 0.3852 - acc: 0.8102 - val_loss: 0.6205 - val_acc: 0.5000
# Epoch 4/10
# 53/53 [==============================] - 133s 3s/step - loss: 0.3421 - acc: 0.8572 - val_loss: 0.5422 - val_acc: 0.6875
# Epoch 5/10
# 53/53 [==============================] - 133s 3s/step - loss: 0.3111 - acc: 0.8783 - val_loss: 0.4976 - val_acc: 0.6875
# Epoch 6/10
# 53/53 [==============================] - 142s 3s/step - loss: 0.2876 - acc: 0.8863 - val_loss: 0.5099 - val_acc: 0.6875
# Epoch 7/10
# 53/53 [==============================] - 133s 3s/step - loss: 0.2687 - acc: 0.8944 - val_loss: 0.5171 - val_acc: 0.6875
# Epoch 8/10
# 53/53 [==============================] - 133s 3s/step - loss: 0.2537 - acc: 0.8982 - val_loss: 0.4740 - val_acc: 0.6875
# Epoch 9/10
# 53/53 [==============================] - 146s 3s/step - loss: 0.2392 - acc: 0.9028 - val_loss: 0.4216 - val_acc: 0.8125
# Epoch 10/10
# 53/53 [==============================] - 151s 3s/step - loss: 0.2276 - acc: 0.9095 - val_loss: 0.4335 - val_acc: 0.7500

# %%
visualize_training_results(results_6)

# %%
#evaluating 
results_train = model_6.evaluate(train_images_resized, train_labels)
results_train
# Out:
# 163/163 [==============================] - 162s 995ms/step - loss: 0.2217 - acc: 0.9120
# [0.22165988385677338, 0.9120015501976013]

# %%
results_test = model_6.evaluate(val_images_resized, val_labels)
results_test
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4335 - acc: 0.7500
# [0.4334558844566345, 0.75]

# %% [markdown]
# ## Model 7 - CNN with Data augmentation

# %%
# Create an ImageDataGenerator instance with data augmentation configurations
datagen = ImageDataGenerator(
    rescale=1./255,  # Rescale pixel values between 0 and 1
    rotation_range=20,  # Randomly rotate images within the range of 20 degrees
    width_shift_range=0.2,  # Randomly shift the width of images by 20% of the total width
    height_shift_range=0.2,  # Randomly shift the height of images by 20% of the total height
    shear_range=0.2,  # Apply shear transformations with a range of 20 degrees
    zoom_range=0.2,  # Randomly zoom images by 20%
    horizontal_flip=True,  # Randomly flip images horizontally
    vertical_flip=True  # Randomly flip images vertically
)

# %%
# Load and augment the training dataset
train_generator = datagen.flow_from_directory(
    train_folder,
    target_size=(128, 128),
    batch_size=32,
    class_mode='binary'
)

# Display a sample of augmented images
augmented_images = next(train_generator)[0]  # Get a batch of augmented images
augmented_labels = next(train_generator)[1]  # Get the corresponding labels

fig, axes = plt.subplots(4, 4, figsize=(10, 10))

for i, ax in enumerate(axes.flat):
    ax.imshow(augmented_images[i])
    ax.axis('off')
    ax.set_title(f"Label: {augmented_labels[i]}")

plt.tight_layout()
plt.show()
# Out:
# Found 5216 images belonging to 2 classes.

# %%
# Display the number of original and augmented images
num_original_images = len(train_generator.filenames)
num_augmented_images = len(train_generator) * train_generator.batch_size

print(f"Number of original images: {num_original_images}")
print(f"Number of augmented images: {num_augmented_images}")
# Out:
# Number of original images: 5216
# Number of augmented images: 5216

# %%
# Build the model
model_7 = models.Sequential()
model_7.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
model_7.add(layers.MaxPooling2D((2, 2)))
model_7.add(layers.Conv2D(64, (3, 3), activation='relu'))
model_7.add(layers.MaxPooling2D((2, 2)))
model_7.add(layers.Conv2D(128, (3, 3), activation='relu'))
model_7.add(layers.MaxPooling2D((2, 2)))
model_7.add(layers.Flatten())
model_7.add(layers.Dense(128, activation='relu'))
model_7.add(layers.Dense(1, activation='sigmoid'))

# %%
# Compile the model
model_7.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# Train the model
results_7 = model_7.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=10,
    validation_data=val_generator,
    validation_steps=len(val_generator)
# Out:
#   File "<ipython-input-136-f7d833734c1f>", line 7
#     validation_steps=len(val_generator)
#                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
visualize_training_results(results_7)

# %%
Ev
